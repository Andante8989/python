# %%
# 크롤링 라이브러리 임포트
from bs4 import BeautifulSoup # 웹에서 가져온 데이터를 정제하는 역할
import requests # 파이썬에서 다이렉트로 자료를 요청하는 역할
from selenium import webdriver # 크롬창을 켜주는 역할
import time # 코드 중간에 딜레이를 넣는 역할
from selenium.webdriver.common.by import By
import codecs

# %%
# 브라우저 켜기
browser = webdriver.Chrome('chromedriver.exe')

# 알라딘 베스트셀러 페이지 접속
browser.get('http://www.ypbooks.co.kr/book_arrange.yp?targetpage=book_week_best&pagetype=5&depth=1')

# 소스코드 변수에 저장하기
source = browser.page_source
# Out:
# C:\Users\이충현\AppData\Local\Temp\ipykernel_17028\161599802.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome('chromedriver.exe')

# %%
source
# Out:
# '<html xmlns="http://www.w3.org/1999/xhtml"><head>\n\t<title>영풍문고 - 서점다운 서점</title>\n\t<meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n\t<meta name="author" content="영풍문고">\n\t<meta name="Keywords" content="영풍문고, 책, 도서, 인터넷 최초 온라인 서점, 온라인서점, 서점, 인터넷서점, 인터넷 도서">\n\t<meta name="title" content="영풍문고 - 서점다운 서점">  \n\t<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\t<meta http-equiv="imagetoolbar" content="false">\n\t<link rel="shortcut icon" href="https://img.ypbooks.co.kr/ypbooks/images/new_favicon.ico" type="image/x-icon">\n\t<link rel="stylesheet" href="/ypbooks/css/search.css" type="text/css">\n\t<link rel="stylesheet" href="/ypbooks/css/books.css" type="text/css">\n\t<link rel="stylesheet" href="/ypbooks/css/reset.css" type="text/css">\n\t<link rel="stylesheet" href="/ypbooks/css/common.css" type="text/css">\n\t<script src="https://cr.acecounter.com/Web/cookiesync.js?gc=AH4A44633083599&amp;rd=1661690347276"></script><script src="https://cr.acecounter.com
# ...

# %%
# 소스코드 파싱
parsed_source = BeautifulSoup(source, "html.parser")

# %%
parsed_source
# Out:
# <html xmlns="http://www.w3.org/1999/xhtml"><head>
# <title>영풍문고 - 서점다운 서점</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="영풍문고" name="author"/>
# <meta content="영풍문고, 책, 도서, 인터넷 최초 온라인 서점, 온라인서점, 서점, 인터넷서점, 인터넷 도서" name="Keywords"/>
# <meta content="영풍문고 - 서점다운 서점" name="title"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="false" http-equiv="imagetoolbar"/>
# <link href="https://img.ypbooks.co.kr/ypbooks/images/new_favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/ypbooks/css/search.css" rel="stylesheet" type="text/css"/>
# <link href="/ypbooks/css/books.css" rel="stylesheet" type="text/css"/>
# <link href="/ypbooks/css/reset.css" rel="stylesheet" type="text/css"/>
# <link href="/ypbooks/css/common.css" rel="stylesheet" type="text/css"/>
# ...

# %%
div_list = parsed_source.find_all("a", class_="boxiconset_bk_tt")

# %%
title_list = []
writer_list = []

# %%
for item in div_list:
    print(item.text)
    title_list.append(item.text)
# Out:
# 하얼빈
# 흔한남매 11
# 불편한 편의점2
# 불편한 편의점(40만부...
# 역행자(10만부 기념 페이크 에디션)
# 세상의 마지막 기차역
# 파친코 1-개정판
# 포켓몬스터 썬&문 포켓몬 전국대도...
# 멘탈을 바꿔야 인생이 바뀐다
# 어서오세요 휴남동 서점입니다(여름 ...
# 흔한남매 이상한 나라의 고전 읽기 1 -...
# 부자아빠 가난한 아빠 1(20주년 특별 ...
# 흔한남매 10
# 작별인사
# 민쩌미 1
# 오늘 밤 세계에서 이 사랑이 사라진다...
# 에그박사 7
# 오늘 밤 세계에서 이 눈물이 사라진다...
# 마법천자문 53-결정을 내려라 결단할 ...
# 포켓몬스터 가라르도감

# %%
div_writer_list = parsed_source.find_all("dd", class_="nbookName")

# %%
div_writer_list
# Out:
# [<dd class="nbookName">김훈 | 문학동네 | 2022.08.03</dd>,
#  <dd class="nbookName">흔한남매,백난도 | 아이세움 | 2022.07.28</dd>,
#  <dd class="nbookName">김호연 | 나무옆의자 | 2022.08.10</dd>,
#  <dd class="nbookName">김호연 | 나무옆의자 | 2021.04.20</dd>,
#  <dd class="nbookName">자청 | 웅진지식하우스 | 2022.05.30</dd>,
#  <dd class="nbookName">무라세다케시 | 모모 | 2022.05.11</dd>,
#  <dd class="nbookName">이민진 | 인플루엔셜 | 2022.07.27</dd>,
#  <dd class="nbookName">편집부 | 대원키즈 | 2017.10.20</dd>,
#  <dd class="nbookName">박세니 | 마인드셋 | 2022.04.30</dd>,
#  <dd class="nbookName">황보름 | 클레이하우스 | 2022.01.17</dd>,
#  <dd class="nbookName">흔한남매(원작),최재훈 | 아이세움 | 2022.06.28</dd>,
#  <dd class="nbookName">로버트기요사키 | 민음인 | 2018.02.22</dd>,
#  <dd class="nbookName">흔한남매,백난도 | 아이세움 | 2022.04.28</dd>,
#  <dd class="nbookName">김영하 | 복복서가 | 2022.05.02</dd>,
#  <dd class="nbookName">최재연 | 샌드박스스토리 | 2022.08.10</dd>,
#  <dd class="nbookName">이치조미사키 | 모모 | 2021.06.28</dd>,
#  <dd class="nbookName">에그박사,박송이 | 아이세움 | 2022.06.15</dd>,
# ...
