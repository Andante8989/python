# %%
# 교보문고 순회 크롤러를 만들어주세요
# 1~200위까지의 책을 txt파일로 저장해주시면 됩니다

# %%
# 크롤링 라이브러리 임포트
from bs4 import BeautifulSoup # 웹에서 가져온 데이터를 정제하는 역할
import requests # 파이썬에서 다이렉트로 자료를 요청하는 역할
from selenium import webdriver # 크롬창을 켜주는 역할
import time # 코드 중간에 딜레이를 넣는 역할
from selenium.webdriver.common.by import By
import codecs

# %%
# 웹드라이버 실행
browser = webdriver.Chrome('chromedriver.exe')

# 교보문고 베스트 첫페이지로 이동
browser.get('http://www.kyobobook.co.kr/bestSellerNew/bestseller.laf')

# 소스코드 저장
source = browser.page_source

# 저장된 소스코드 파싱
parsed_source = BeautifulSoup(source, "html.parser")

# 위에는 페이지 전체를 가져온것이므로 부분으로 가져와야됨, 정보를 포함하는 최소단위 ul태그 가져옴
div_tag_title_list = parsed_source.find_all("ul", class_="list_type01")
len(div_tag_title_list)  # 1개라고 출력됨

# 리스트여서 1개라고 나오므로 인덱싱으로 꺼내서 추출해야됨
ul_tag_type01 = div_tag_title_list[0]

len(div_tag_title_list)
# Out:
# C:\Users\이충현\AppData\Local\Temp\ipykernel_3184\85186819.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome('chromedriver.exe')
# 50

# %%
# 책제목 50개 가져옴, 리스트에저장
div_tag_title_list = ul_tag_type01.find_all("div", class_="title")
for item in div_tag_title_list:
    print(item.text.strip())
    title_list.append(item.text.strip())
# Out:
# 역행자
# 불편한 편의점(40만부 기념 벚꽃 에디션)
# 세상의 마지막 기차역
# 계속 가보겠습니다
# 작별인사
# 기분을 관리하면 인생이 관리된다
# 이상한 과자 가게 전천당 15
# 유럽 도시 기행 2
# 어서 오세요, 휴남동 서점입니다 (여름 숲 에디션)
# 친밀한 이방인
# 나 혼자만 레벨업 6(만화)
# 인플레이션에서 살아남기
# 마법천자문 53: 결정을 내리다! 결단할 결
# 매일을 헤엄치는 법
# 변화하는 세계 질서
# 호감 가는 말투에는 비밀이 있다
# 눈물 한 방울
# 해커스 토익 기출 보카 TOEIC VOCA(개정판 5판)
# 최재천의 공부
# 나를 내려놓으니 내가 좋아졌다
# 멘탈을 바꿔야 인생이 바뀐다
# 에그박사 7
# 어느 날, 내 죽음에 네가 들어왔다
# 내 삶을 변화시키는 감사의 기적(양장본 Hardcover)
# 방과 후 소년 하나코 군
# 나라면 나와 결혼할까?
# 입지 센스
# 달러구트 꿈 백화점
# 기억력 천재 게으른 뇌를 깨워라
# 부자 아빠 가난한 아빠 1(20주년 특별 기념판)(개정증보판)
# 마음의 법칙
# 원피스 102: 천왕산
# 흔한남매 10
# 흔한남매 과학 탐험대 5: 물리 1(양장본 HardCover)
# 물고기는 존재하지 않는다
# 그릿(100쇄 기념 리커버 에디션)
# 부를 재편하는 금융 대혁명
# 원펀맨(One Punch Man) 25
# 테라피스트
# 포켓몬스터 썬&문 포켓몬 전국대도감
# 모든 것은 기본에서 시작한다
# 영어독립 365
# 데일 카네기 인간관계론
# 오늘 밤, 세계에서 이 사랑이 사라진다 해도
# 오은영의 화해
# 이어령의 마지막 수업
# 부의 추월차선(10주년 스페셜 에디션)
# 그리스 로마 신화 29: 오디세우스의 험난한 모험
# 인간 실격(세계문학전집 103)
# 삶의 격(일상 인문학 3)

# %%
# 저자 50 개 가져옴, 리스트에저장
div_tag_writer_list = ul_tag_type01.find_all("div", class_="author")
for item in div_tag_writer_list:
    print(item.text.strip().replace("\n", "").replace("\t", ""))
    author_list.append(item.text.strip().replace("\n", "").replace("\t", ""))
# Out:
# 자청| 웅진지식하우스| 2022년 05월 30일
# 김호연| 나무옆의자| 2021년 04월 20일
# 무라세 다케시| 모모| 2022년 05월 09일
# 임은정| 메디치미디어| 2022년 07월 22일
# 김영하| 복복서가| 2022년 05월 02일
# 김다슬| 클라우디아| 2022년 04월 12일
# 히로시마 레이코| 길벗스쿨| 2022년 07월 11일
# 유시민| 생각의길| 2022년 07월 09일
# 황보름| 클레이하우스| 2022년 01월 17일
# 정한아| 문학동네| 2017년 10월 13일
# 장성락(REDICE STUDIO)저자 더보기추공 (원작)현군 (각색)| 디앤씨웹툰비즈| 2022년 07월 25일
# 오건영| 페이지2북스| 2022년 05월 23일
# 유대영| 아울북| 2022년 07월 12일
# 이연| 푸른숲| 2022년 07월 20일
# 레이 달리오| 한빛비즈| 2022년 06월 01일
# 장신웨| 리드리드출판| 2022년 08월 11일
# 이어령| 김영사| 2022년 06월 30일
# David Cho| 해커스어학연구소| 2022년 03월 14일
# 최재천저자 더보기안희경| 김영사| 2022년 05월 18일
# 네모토 히로유키| 밀리언서재| 2022년 06월 24일
# 박세니| 마인드셋(Mindset)| 2022년 04월 30일
# 에그박사 (원작)저자 더보기박송이| 미래엔아이세움| 2022년 06월 15일
# 세이카 료겐| 모모| 2022년 05월 09일
# 황성주| 정민미디어| 2022년 07월 01일
# AidaIro| 서울미디어코믹스(서울문화사)| 2022년 07월 30일
# 후이| 미디어숲| 2022년 08월 10일
# 훨훨(박성혜)| 다산북스| 2022년 07월 11일
# 이미예| 팩토리나인| 2020년 07월 08일
# 개러스 무어| 미디어숲| 2022년 07월 20일
# 로버트 기요사키| 민음인| 2018년 02월 22일
# 폴커 키츠저자 더보기마누엘 투쉬| 포레스트북스| 2022년 02월 10일
# Eiichiro Oda| 대원씨아이| 2022년 06월 30일
# 흔한남매 (원작)저자 더보기백난도| 미래엔아이세움| 2022년 04월 28일
# 흔한남매 (원작)저자 더보기이현진닥터 스코| 주니어김영사| 2022년 06월 16일
# 룰루 밀러| 곰출판| 2021년 12월 17일
# 앤절라 더크워스| 비즈니스북스| 2019년 02월 20일
# 마리온 라부저자 더보기니콜라스 데프렌스| 미디어숲| 2022년 07월 07일
# One (원작)| 대원씨아이| 2022년 07월 31일
# B. A. 패리스| 모모| 2021년 12월 06일
# 대원키즈 편집부| 대원키즈| 2017년 10월 19일
# 손웅정| 수오서재| 2021년 10월 15일
# 영어독립단어 콘텐츠팀저자 더보기신미주| 상상스퀘어| 2022년 06월 29일
# 데일 카네기| 현대지성| 2019년 10월 07일
# 이치조 미사키| 모모| 2021년 06월 28일
# 오은영| 코리아닷컴| 2019년 01월 10일
# 김지수저자 더보기이어령| 열림원| 2021년 10월 28일
# 엠제이 드마코| 토트| 2022년 02월 04일
# 박시연| 아울북| 2022년 07월 06일
# 다자이 오사무| 민음사| 2012년 04월 10일
# 페터 비에리| 은행나무| 2014년 10월 29일

# %%
# 가격 50 개가져옴, 리스트에저장
div_tag_price_list = ul_tag_type01.find_all("strong", class_="book_price")
for item in div_tag_price_list:
    print(item.text)
    price_list.append(item.text)
# Out:
# 15,750원
# 12,600원
# 12,600원
# 16,200원
# 12,600원
# 15,840원
# 11,700원
# 15,750원
# 13,500원
# 11,700원
# 13,500원
# 16,920원
# 12,600원
# 14,400원
# 34,200원
# 15,120원
# 14,220원
# 11,610원
# 14,850원
# 14,400원
# 14,220원
# 13,050원
# 13,500원
# 16,020원
# 5,400원
# 15,120원
# 18,000원
# 12,420원
# 14,220원
# 14,220원
# 14,400원
# 4,950원
# 12,150원
# 12,600원
# 15,300원
# 14,400원
# 19,800원
# 4,950원
# 14,400원
# 8,550원
# 14,400원
# 22,500원
# 10,350원
# 12,600원
# 14,400원
# 14,850원
# 15,750원
# 12,600원
# 8,100원
# 14,400원

# %%
# 제목, 가격, 저자 정보를 저장할 리스트 생성
title_list = []
price_list = []
author_list = []

# %%
title_list
# Out:
# ['역행자',
#  '불편한 편의점(40만부 기념 벚꽃 에디션)',
#  '세상의 마지막 기차역',
#  '계속 가보겠습니다',
#  '작별인사',
#  '기분을 관리하면 인생이 관리된다',
#  '이상한 과자 가게 전천당 15',
#  '유럽 도시 기행 2',
#  '어서 오세요, 휴남동 서점입니다 (여름 숲 에디션)',
#  '친밀한 이방인',
#  '나 혼자만 레벨업 6(만화)',
#  '인플레이션에서 살아남기',
#  '마법천자문 53: 결정을 내리다! 결단할 결',
#  '매일을 헤엄치는 법',
#  '변화하는 세계 질서',
#  '호감 가는 말투에는 비밀이 있다',
#  '눈물 한 방울',
#  '해커스 토익 기출 보카 TOEIC VOCA(개정판 5판)',
#  '최재천의 공부',
#  '나를 내려놓으니 내가 좋아졌다',
#  '멘탈을 바꿔야 인생이 바뀐다',
#  '에그박사 7',
#  '어느 날, 내 죽음에 네가 들어왔다',
#  '내 삶을 변화시키는 감사의 기적(양장본 Hardcover)',
#  '방과 후 소년 하나코 군',
#  '나라면 나와 결혼할까?',
#  '입지 센스',
#  '달러구트 꿈 백화점',
#  '기억력 천재 게으른 뇌를 깨워라',
#  '부자 아빠 가난한 아빠 1(20주년 특별 기념판)(개정증보판)',
#  '마음의 법칙',
#  '원피스 102: 천왕산',
#  '흔한남매 10',
#  '흔한남매 과학 탐험대 5: 물리 1(양장본 HardCover)',
#  '물고기는 존재하지 않는다',
#  '그릿(100쇄 기념 리커버 에디션)',
#  '부를 재편하는 금융 대혁명',
#  '원펀맨(One Punch Man) 25',
#  '테라피스트',
#  '포켓몬스터 썬&문 포켓몬 전국대도감',
#  '모든 것은 기본에서 시작한다',
#  '영어독립 365',
#  '데일 카네기 인간관계론',
#  '오늘 밤, 세계에서 이 사랑이 사라진다 해도',
#  '오은영의 화해',
#  '이어령의 마지막 수업',
#  '부의 추월차선(10주년 스페셜 에디션)',
#  '그리스 로마 신화 29: 오디세우스의 험난한 모험',
#  '인간 실격(세계문학전집 103)',
#  '삶의 격(일상 인문학 3)']

# %%
for i in range(len(title_list)):
    print(title_list[i])
    print(author_list[i])
    print(price_list[i])
    print("---------------------")
# Out:
# 역행자
# 자청| 웅진지식하우스| 2022년 05월 30일
# 15,750원
# ---------------------
# 불편한 편의점(40만부 기념 벚꽃 에디션)
# 김호연| 나무옆의자| 2021년 04월 20일
# 12,600원
# ---------------------
# 세상의 마지막 기차역
# 무라세 다케시| 모모| 2022년 05월 09일
# 12,600원
# ---------------------
# 계속 가보겠습니다
# 임은정| 메디치미디어| 2022년 07월 22일
# 16,200원
# ---------------------
# 작별인사
# 김영하| 복복서가| 2022년 05월 02일
# 12,600원
# ---------------------
# 기분을 관리하면 인생이 관리된다
# 김다슬| 클라우디아| 2022년 04월 12일
# 15,840원
# ---------------------
# 이상한 과자 가게 전천당 15
# 히로시마 레이코| 길벗스쿨| 2022년 07월 11일
# 11,700원
# ---------------------
# 유럽 도시 기행 2
# 유시민| 생각의길| 2022년 07월 09일
# 15,750원
# ---------------------
# 어서 오세요, 휴남동 서점입니다 (여름 숲 에디션)
# 황보름| 클레이하우스| 2022년 01월 17일
# 13,500원
# ---------------------
# 친밀한 이방인
# 정한아| 문학동네| 2017년 10월 13일
# 11,700원
# ---------------------
# 나 혼자만 레벨업 6(만화)
# 장성락(REDICE STUDIO)저자 더보기추공 (원작)현군 (각색)| 디앤씨웹툰비즈| 2022년 07월 25일
# 13,500원
# ---------------------
# 인플레이션에서 살아남기
# 오건영| 페이지2북스| 2022년 05월 23일
# 16,920원
# ---------------------
# 마법천자문 53: 결정을 내리다! 결단할 결
# 유대영| 아울북| 2022년 07월 12일
# 12,600원
# ---------------------
# 매일을 헤엄치는 법
# 이연| 푸른숲| 2022년 07월 20일
# 14,400원
# ---------------------
# 변화하는 세계 질서
# 레이 달리오| 한빛비즈| 2022년 06월 01일
# 34,200원
# ---------------------
# 호감 가는 말투에는 비밀이 있다
# 장신웨| 리드리드출판| 2022년 08월 11일
# 15,120원
# ---------------------
# 눈물 한 방울
# 이어령| 김영사| 2022년 06월 30일
# 14,220원
# ---------------------
# 해커스 토익 기출 보카 TOEIC VOCA(개정판 5판)
# David Cho| 해커스어학연구소| 2022년 03월 14일
# 11,610원
# ---------------------
# 최재천의 공부
# 최재천저자 더보기안희경| 김영사| 2022년 05월 18일
# 14,850원
# ---------------------
# 나를 내려놓으니 내가 좋아졌다
# 네모토 히로유키| 밀리언서재| 2022년 06월 24일
# 14,400원
# ---------------------
# 멘탈을 바꿔야 인생이 바뀐다
# 박세니| 마인드셋(Mindset)| 2022년 04월 30일
# 14,220원
# ---------------------
# 에그박사 7
# 에그박사 (원작)저자 더보기박송이| 미래엔아이세움| 2022년 06월 15일
# 13,050원
# ---------------------
# 어느 날, 내 죽음에 네가 들어왔다
# 세이카 료겐| 모모| 2022년 05월 09일
# 13,500원
# ---------------------
# 내 삶을 변화시키는 감사의 기적(양장본 Hardcover)
# 황성주| 정민미디어| 2022년 07월 01일
# 16,020원
# ---------------------
# 방과 후 소년 하나코 군
# AidaIro| 서울미디어코믹스(서울문화사)| 2022년 07월 30일
# 5,400원
# ---------------------
# 나라면 나와 결혼할까?
# 후이| 미디어숲| 2022년 08월 10일
# 15,120원
# ---------------------
# 입지 센스
# 훨훨(박성혜)| 다산북스| 2022년 07월 11일
# 18,000원
# ---------------------
# 달러구트 꿈 백화점
# 이미예| 팩토리나인| 2020년 07월 08일
# 12,420원
# ---------------------
# 기억력 천재 게으른 뇌를 깨워라
# 개러스 무어| 미디어숲| 2022년 07월 20일
# 14,220원
# ---------------------
# 부자 아빠 가난한 아빠 1(20주년 특별 기념판)(개정증보판)
# 로버트 기요사키| 민음인| 2018년 02월 22일
# 14,220원
# ---------------------
# 마음의 법칙
# 폴커 키츠저자 더보기마누엘 투쉬| 포레스트북스| 2022년 02월 10일
# 14,400원
# ---------------------
# 원피스 102: 천왕산
# Eiichiro Oda| 대원씨아이| 2022년 06월 30일
# 4,950원
# ---------------------
# 흔한남매 10
# 흔한남매 (원작)저자 더보기백난도| 미래엔아이세움| 2022년 04월 28일
# 12,150원
# ---------------------
# 흔한남매 과학 탐험대 5: 물리 1(양장본 HardCover)
# 흔한남매 (원작)저자 더보기이현진닥터 스코| 주니어김영사| 2022년 06월 16일
# 12,600원
# ---------------------
# 물고기는 존재하지 않는다
# 룰루 밀러| 곰출판| 2021년 12월 17일
# 15,300원
# ---------------------
# 그릿(100쇄 기념 리커버 에디션)
# 앤절라 더크워스| 비즈니스북스| 2019년 02월 20일
# 14,400원
# ---------------------
# 부를 재편하는 금융 대혁명
# 마리온 라부저자 더보기니콜라스 데프렌스| 미디어숲| 2022년 07월 07일
# 19,800원
# ---------------------
# 원펀맨(One Punch Man) 25
# One (원작)| 대원씨아이| 2022년 07월 31일
# 4,950원
# ---------------------
# 테라피스트
# B. A. 패리스| 모모| 2021년 12월 06일
# 14,400원
# ---------------------
# 포켓몬스터 썬&문 포켓몬 전국대도감
# 대원키즈 편집부| 대원키즈| 2017년 10월 19일
# 8,550원
# ---------------------
# 모든 것은 기본에서 시작한다
# 손웅정| 수오서재| 2021년 10월 15일
# 14,400원
# ---------------------
# 영어독립 365
# 영어독립단어 콘텐츠팀저자 더보기신미주| 상상스퀘어| 2022년 06월 29일
# 22,500원
# ---------------------
# 데일 카네기 인간관계론
# 데일 카네기| 현대지성| 2019년 10월 07일
# 10,350원
# ---------------------
# 오늘 밤, 세계에서 이 사랑이 사라진다 해도
# 이치조 미사키| 모모| 2021년 06월 28일
# 12,600원
# ---------------------
# 오은영의 화해
# 오은영| 코리아닷컴| 2019년 01월 10일
# 14,400원
# ---------------------
# 이어령의 마지막 수업
# 김지수저자 더보기이어령| 열림원| 2021년 10월 28일
# 14,850원
# ---------------------
# 부의 추월차선(10주년 스페셜 에디션)
# 엠제이 드마코| 토트| 2022년 02월 04일
# 15,750원
# ---------------------
# 그리스 로마 신화 29: 오디세우스의 험난한 모험
# 박시연| 아울북| 2022년 07월 06일
# 12,600원
# ---------------------
# 인간 실격(세계문학전집 103)
# 다자이 오사무| 민음사| 2012년 04월 10일
# 8,100원
# ---------------------
# 삶의 격(일상 인문학 3)
# 페터 비에리| 은행나무| 2014년 10월 29일
# 14,400원
# ---------------------

# %%
browser = webdriver.Chrome('chromedriver.exe')


f = codecs.open("c:/crawler2/kyobo.txt", mode="w", encoding="utf-8")

for i in range(1, 5):
   
    browser.get('https://www.kyobobook.co.kr/bestSellerNew/bestseller.laf?targetPage=%s' % i)
    time.sleep(3)
    
    title_list = []
    price_list = []
    author_list = []
    
    # 소스코드 저장
    source = browser.page_source

    # 저장된 소스코드 파싱
    parsed_source = BeautifulSoup(source, "html.parser")

    # 위에는 페이지 전체를 가져온것이므로 부분으로 가져와야됨, 정보를 포함하는 최소단위 ul태그 가져옴
    div_tag_title_list = parsed_source.find_all("ul", class_="list_type01")
    len(div_tag_title_list)  # 1개라고 출력됨

    # 리스트여서 1개라고 나오므로 인덱싱으로 꺼내서 추출해야됨
    ul_tag_type01 = div_tag_title_list[0]
    
    # 제목 50 개 가져옴, 리스트에 저장
    div_tag_title_list = ul_tag_type01.find_all("div", class_="title")
    for item in div_tag_title_list:
        title_list.append(item.text.strip())
        
    # 저자 50 개 가져옴, 리스트에저장
    div_tag_writer_list = ul_tag_type01.find_all("div", class_="author")
    for item in div_tag_writer_list:
        author_list.append(item.text.strip().replace("\n", "").replace("\t", ""))
        
    # 가격 50 개가져옴, 리스트에저장
    div_tag_price_list = ul_tag_type01.find_all("strong", class_="book_price")
    for item in div_tag_price_list:
        price_list.append(item.text)
    
    for i in range(len(title_list)):
        print(title_list[i])
        print(author_list[i])
        print(price_list[i])
        print("---------------------")
    
f.close()
# Out:
# C:\Users\이충현\AppData\Local\Temp\ipykernel_3184\816943303.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome('chromedriver.exe')
# 역행자
# 자청| 웅진지식하우스| 2022년 05월 30일
# 15,750원
# ---------------------
# 불편한 편의점(40만부 기념 벚꽃 에디션)
# 김호연| 나무옆의자| 2021년 04월 20일
# 12,600원
# ---------------------
# 세상의 마지막 기차역
# 무라세 다케시| 모모| 2022년 05월 09일
# 12,600원
# ---------------------
# 계속 가보겠습니다
# 임은정| 메디치미디어| 2022년 07월 22일
# 16,200원
# ---------------------
# 작별인사
# 김영하| 복복서가| 2022년 05월 02일
# 12,600원
# ---------------------
# 기분을 관리하면 인생이 관리된다
# 김다슬| 클라우디아| 2022년 04월 12일
# 15,840원
# ---------------------
# 이상한 과자 가게 전천당 15
# 히로시마 레이코| 길벗스쿨| 2022년 07월 11일
# 11,700원
# ---------------------
# 유럽 도시 기행 2
# 유시민| 생각의길| 2022년 07월 09일
# 15,750원
# ---------------------
# 어서 오세요, 휴남동 서점입니다 (여름 숲 에디션)
# 황보름| 클레이하우스| 2022년 01월 17일
# 13,500원
# ---------------------
# 친밀한 이방인
# 정한아| 문학동네| 2017년 10월 13일
# 11,700원
# ---------------------
# 나 혼자만 레벨업 6(만화)
# 장성락(REDICE STUDIO)저자 더보기추공 (원작)현군 (각색)| 디앤씨웹툰비즈| 2022년 07월 25일
# 13,500원
# ---------------------
# 인플레이션에서 살아남기
# 오건영| 페이지2북스| 2022년 05월 23일
# 16,920원
# ---------------------
# 마법천자문 53: 결정을 내리다! 결단할 결
# 유대영| 아울북| 2022년 07월 12일
# 12,600원
# ---------------------
# 매일을 헤엄치는 법
# 이연| 푸른숲| 2022년 07월 20일
# 14,400원
# ---------------------
# 변화하는 세계 질서
# 레이 달리오| 한빛비즈| 2022년 06월 01일
# 34,200원
# ---------------------
# 호감 가는 말투에는 비밀이 있다
# 장신웨| 리드리드출판| 2022년 08월 11일
# 15,120원
# ---------------------
# 눈물 한 방울
# 이어령| 김영사| 2022년 06월 30일
# 14,220원
# ---------------------
# 해커스 토익 기출 보카 TOEIC VOCA(개정판 5판)
# David Cho| 해커스어학연구소| 2022년 03월 14일
# 11,610원
# ---------------------
# 최재천의 공부
# 최재천저자 더보기안희경| 김영사| 2022년 05월 18일
# 14,850원
# ---------------------
# 나를 내려놓으니 내가 좋아졌다
# 네모토 히로유키| 밀리언서재| 2022년 06월 24일
# 14,400원
# ---------------------
# 멘탈을 바꿔야 인생이 바뀐다
# 박세니| 마인드셋(Mindset)| 2022년 04월 30일
# 14,220원
# ---------------------
# 에그박사 7
# 에그박사 (원작)저자 더보기박송이| 미래엔아이세움| 2022년 06월 15일
# 13,050원
# ---------------------
# 어느 날, 내 죽음에 네가 들어왔다
# 세이카 료겐| 모모| 2022년 05월 09일
# 13,500원
# ---------------------
# 내 삶을 변화시키는 감사의 기적(양장본 Hardcover)
# 황성주| 정민미디어| 2022년 07월 01일
# 16,020원
# ---------------------
# 방과 후 소년 하나코 군
# AidaIro| 서울미디어코믹스(서울문화사)| 2022년 07월 30일
# 5,400원
# ---------------------
# 나라면 나와 결혼할까?
# 후이| 미디어숲| 2022년 08월 10일
# 15,120원
# ---------------------
# 입지 센스
# 훨훨(박성혜)| 다산북스| 2022년 07월 11일
# 18,000원
# ---------------------
# 달러구트 꿈 백화점
# 이미예| 팩토리나인| 2020년 07월 08일
# 12,420원
# ---------------------
# 기억력 천재 게으른 뇌를 깨워라
# 개러스 무어| 미디어숲| 2022년 07월 20일
# 14,220원
# ---------------------
# 부자 아빠 가난한 아빠 1(20주년 특별 기념판)(개정증보판)
# 로버트 기요사키| 민음인| 2018년 02월 22일
# 14,220원
# ---------------------
# 마음의 법칙
# 폴커 키츠저자 더보기마누엘 투쉬| 포레스트북스| 2022년 02월 10일
# 14,400원
# ---------------------
# 원피스 102: 천왕산
# Eiichiro Oda| 대원씨아이| 2022년 06월 30일
# 4,950원
# ---------------------
# 흔한남매 10
# 흔한남매 (원작)저자 더보기백난도| 미래엔아이세움| 2022년 04월 28일
# 12,150원
# ---------------------
# 흔한남매 과학 탐험대 5: 물리 1(양장본 HardCover)
# 흔한남매 (원작)저자 더보기이현진닥터 스코| 주니어김영사| 2022년 06월 16일
# 12,600원
# ---------------------
# 물고기는 존재하지 않는다
# 룰루 밀러| 곰출판| 2021년 12월 17일
# 15,300원
# ---------------------
# 그릿(100쇄 기념 리커버 에디션)
# 앤절라 더크워스| 비즈니스북스| 2019년 02월 20일
# 14,400원
# ---------------------
# 부를 재편하는 금융 대혁명
# 마리온 라부저자 더보기니콜라스 데프렌스| 미디어숲| 2022년 07월 07일
# 19,800원
# ---------------------
# 원펀맨(One Punch Man) 25
# One (원작)| 대원씨아이| 2022년 07월 31일
# 4,950원
# ---------------------
# 테라피스트
# B. A. 패리스| 모모| 2021년 12월 06일
# 14,400원
# ---------------------
# 포켓몬스터 썬&문 포켓몬 전국대도감
# 대원키즈 편집부| 대원키즈| 2017년 10월 19일
# 8,550원
# ---------------------
# 모든 것은 기본에서 시작한다
# 손웅정| 수오서재| 2021년 10월 15일
# 14,400원
# ---------------------
# 영어독립 365
# 영어독립단어 콘텐츠팀저자 더보기신미주| 상상스퀘어| 2022년 06월 29일
# 22,500원
# ---------------------
# 데일 카네기 인간관계론
# 데일 카네기| 현대지성| 2019년 10월 07일
# 10,350원
# ---------------------
# 오늘 밤, 세계에서 이 사랑이 사라진다 해도
# 이치조 미사키| 모모| 2021년 06월 28일
# 12,600원
# ---------------------
# 오은영의 화해
# 오은영| 코리아닷컴| 2019년 01월 10일
# 14,400원
# ---------------------
# 이어령의 마지막 수업
# 김지수저자 더보기이어령| 열림원| 2021년 10월 28일
# 14,850원
# ---------------------
# 부의 추월차선(10주년 스페셜 에디션)
# 엠제이 드마코| 토트| 2022년 02월 04일
# 15,750원
# ---------------------
# 그리스 로마 신화 29: 오디세우스의 험난한 모험
# 박시연| 아울북| 2022년 07월 06일
# 12,600원
# ---------------------
# 인간 실격(세계문학전집 103)
# 다자이 오사무| 민음사| 2012년 04월 10일
# 8,100원
# ---------------------
# 삶의 격(일상 인문학 3)
# 페터 비에리| 은행나무| 2014년 10월 29일
# 14,400원
# ---------------------
# 당신은 결국 무엇이든 해내는 사람
# 김상현| 필름(Feelm)| 2022년 04월 20일
# 13,500원
# ---------------------
# 다정한 것이 살아남는다(양장본 HardCover)
# 브라이언 헤어저자 더보기버네사 우즈| 디플롯| 2021년 07월 26일
# 19,800원
# ---------------------
# 넛지(파이널 에디션)(양장본 HardCover)
# 리처드 탈러저자 더보기캐스 선스타인| 리더스북| 2022년 06월 20일
# 19,800원
# ---------------------
# 밥 프록터 부의 확신(양장본 Hardcover)
# 밥 프록터| 비즈니스북스| 2022년 07월 12일
# 14,400원
# ---------------------
# 설민석의 한국사 대모험 21
# 설민석저자 더보기스토리박스| 단꿈아이| 2022년 05월 27일
# 11,700원
# ---------------------
# 아몬드(100만 부 기념 특별판)(양장본 HardCover)
# 손원평| 창비| 2022년 05월 12일
# 10,800원
# ---------------------
# 원씽(The One Thing)(리커버 특별판)
# 게리 켈러저자 더보기제이 파파산| 비즈니스북스| 2013년 08월 30일
# 12,600원
# ---------------------
# 돈의 속성(200쇄 리커버에디션)(개정증보판)(양장본 HardCover)
# 김승호| 스노우폭스북스| 2020년 06월 15일
# 16,020원
# ---------------------
# 인천 부동산의 미래(양장본 Hardcover)
# 스마트튜브(김학렬)| 원앤원북스| 2022년 07월 21일
# 20,700원
# ---------------------
# 스파이 패밀리 9
# Tatsuya Endo| 학산문화사| 2022년 06월 08일
# 5,400원
# ---------------------
# 저만치 혼자서(양장본 Hardcover)
# 김훈| 문학동네| 2022년 06월 01일
# 13,500원
# ---------------------
# 포켓몬 전국 캐릭터 대도감: 다이아몬드 펄
# 학산문화사 편집부| 학산문화사| 2020년 08월 20일
# 12,600원
# ---------------------
# 흔한남매의 흔한 호기심 6
# 흔한남매 (원작)저자 더보기안치현| 미래엔아이세움| 2022년 06월 08일
# 11,700원
# ---------------------
# 무엇이 옳은가
# 후안 엔리케스| 세계사| 2022년 04월 19일
# 16,020원
# ---------------------
# 데일 카네기 자기관리론(1948년 초판 완역본)
# 데일 카네기| 현대지성| 2021년 01월 13일
# 10,350원
# ---------------------
# 월급쟁이 부자로 은퇴하라(10만 부 돌파 기념 증보판)
# 너나위| 알에이치코리아| 2022년 06월 20일
# 17,820원
# ---------------------
# 여기는 커스터드, 특별한 도시락을 팝니다
# 가토 겐| 필름(Feelm)| 2022년 07월 15일
# 13,500원
# ---------------------
# 운명을 바꾸는 부동산 투자 수업: 기초편
# 정태익| 리더스북| 2022년 03월 22일
# 15,120원
# ---------------------
# 내가 틀릴 수도 있습니다
# 비욘 나티코 린데블라드| 다산초당| 2022년 04월 18일
# 14,400원
# ---------------------
# 백년허리 2: 치료편
# 정선근| 언탱글링| 2021년 05월 13일
# 16,650원
# ---------------------
# 나로서 충분히 괜찮은 사람
# 김재식| 북로망스| 2022년 05월 10일
# 14,400원
# ---------------------
# 칵테일, 러브, 좀비 (리커버)(안전가옥 쇼-트 2)
# 조예은| 안전가옥| 2020년 04월 13일
# 9,000원
# ---------------------
# 나를 살게 하는 것들
# 김창옥| 수오서재| 2022년 07월 07일
# 14,400원
# ---------------------
# 아무것도 하지 않으면 아무것도 달라지지 않는다
# 고윤(페이서스 코리아)| 마인드셋(Mindset)| 2022년 07월 03일
# 12,960원
# ---------------------
# 마음을 업데이트할 시간입니다
# 남궁원| 모모북스| 2022년 07월 18일
# 14,220원
# ---------------------
# 흔한남매 이상한 나라의 고전 읽기 1: 춘향전 토끼전 옹고집전
# 흔한남매 (원작)저자 더보기최재훈| 미래엔아이세움| 2022년 06월 28일
# 12,600원
# ---------------------
# 한 개의 기쁨이 천 개의 슬픔을 이긴다: 삶과 태도에 관하여(조우성 변호사 에세이 1)
# 조우성| 서삼독| 2022년 07월 07일
# 13,320원
# ---------------------
# 지정학의 힘
# 김동기| 아카넷| 2020년 11월 18일
# 16,200원
# ---------------------
# 나는 당신이 행복했으면 좋겠습니다
# 박찬위| 하이스트| 2021년 11월 25일
# 12,420원
# ---------------------
# 구의 증명(은행나무 노벨라 7)
# 최진영| 은행나무| 2015년 03월 30일
# 7,200원
# ---------------------
# 해커스 토익 RC 리딩(Reading)(개정판 8판)
# David Cho| 해커스어학연구소| 2022년 01월 10일
# 16,920원
# ---------------------
# 긴긴밤(보름달문고 83)
# 루리| 문학동네| 2021년 02월 03일
# 10,350원
# ---------------------
# 사피엔스
# 유발 하라리| 김영사| 2015년 11월 24일
# 19,800원
# ---------------------
# 믿음에 대하여
# 박상영| 문학동네| 2022년 07월 20일
# 13,050원
# ---------------------
# 미드나잇 라이브러리(1주년 스페셜 에디션)
# 매트 헤이그| 인플루엔셜| 2021년 04월 28일
# 14,220원
# ---------------------
# 다섯번째 산(양장본 HardCover)
# 파울로 코엘료| 문학동네| 2022년 07월 12일
# 13,500원
# ---------------------
# 너무 잘하려고 애쓰지 마라
# 나태주| 열림원| 2022년 05월 31일
# 12,600원
# ---------------------
# 주술회전 19: 도쿄 제1콜로니(화내는 남자)
# Gege Akutami| 서울미디어코믹스(서울문화사)| 2022년 06월 01일
# 5,400원
# ---------------------
# 달러구트 꿈 백화점 2
# 이미예| 팩토리나인| 2021년 07월 27일
# 12,420원
# ---------------------
# 도올주역강해(양장본 Hardcover)
# 도올(김용옥)| 통나무| 2022년 08월 03일
# 35,100원
# ---------------------
# 해커스 보카(Hackers Vocabulary)(개정판 2판)
# David Cho| 해커스어학연구소| 2021년 12월 13일
# 15,210원
# ---------------------
# 오백 년째 열다섯(텍스트T 1)
# 김혜정| 위즈덤하우스| 2022년 01월 28일
# 11,250원
# ---------------------
# ETS 토익 기출 VOCA 출제기관 공식수험서(개정판)
# ETS| YBM| 2018년 06월 05일
# 11,610원
# ---------------------
# 백년운동
# 정선근| 아티잔| 2019년 10월 31일
# 17,550원
# ---------------------
# 타이탄의 도구들(블랙 에디션)
# 팀 페리스| 토네이도| 2022년 06월 20일
# 16,200원
# ---------------------
# 책들의 부엌
# 김지혜| 팩토리나인| 2022년 05월 12일
# 13,050원
# ---------------------
# 행성 1(양장본 HardCover)
# 베르나르 베르베르| 열린책들| 2022년 05월 30일
# 15,120원
# ---------------------
# 나의 MBTI가 궁금하단 마리몽
# 김소나| 더모던| 2021년 11월 30일
# 14,220원
# ---------------------
# 꽁꽁꽁 아이스크림(그림책이 참 좋아 91)(양장본 Hardcover)
# 윤정주| 책읽는곰| 2022년 07월 15일
# 12,600원
# ---------------------
# 지구 끝의 온실(여름 에디션)
# 김초엽| 자이언트북스| 2021년 08월 18일
# 13,500원
# ---------------------
# 세상에서 가장 짧은 한국사
# 김재원| 빅피시| 2022년 06월 15일
# 16,020원
# ---------------------
# 둥실이네 떡집(난 책읽기가 좋아)(양장본 Hardcover)
# 김리리| 비룡소| 2022년 04월 22일
# 9,900원
# ---------------------
# 거의 모든 행동 표현의 영어
# 서영조| 사람in| 2022년 03월 10일
# 14,400원
# ---------------------
# H마트에서 울다
# 미셸 자우너| 문학동네| 2022년 02월 28일
# 14,400원
# ---------------------
# 포켓몬스터 가라르 도감
# 대원키즈 편집부| 대원키즈| 2021년 05월 20일
# 10,800원
# ---------------------
# 총 균 쇠
# 재레드 다이아몬드| 문학사상| 2005년 12월 19일
# 25,200원
# ---------------------
# 바로 쓰는 영어
# 셀리| 넥서스| 2022년 07월 20일
# 16,200원
# ---------------------
# 밝은 밤
# 최은영| 문학동네| 2021년 07월 27일
# 13,050원
# ---------------------
# 나는 왜 나를 함부로 대할까
# 문요한| 해냄출판사| 2022년 06월 30일
# 15,120원
# ---------------------
# 도쿄 에일리언즈 3(더블특장판)
# NAOE| 서울미디어코믹스(서울문화사)| 2022년 06월 30일
# 4,500원
# ---------------------
# 계속 가봅시다 남는 게 체력인데
# 정김경숙| 웅진지식하우스| 2022년 07월 08일
# 14,850원
# ---------------------
# 저주토끼(3판)
# 정보라| 아작| 2022년 04월 01일
# 13,320원
# ---------------------
# 곰돌이 푸 WINNIE-THE-POOH(초판본)
# 알란 알렉산더 밀른| 피카(FIKA)| 2022년 07월 22일
# 13,500원
# ---------------------
# 토익 단기공략 750+(LC+RC)(ETS)
# ETS| YBM| 2020년 08월 20일
# 16,200원
# ---------------------
# 해커스 토익 LC 리스닝(Listening)(개정판 8판)
# David Cho| 해커스어학연구소| 2022년 01월 10일
# 16,920원
# ---------------------
# 수박 수영장(양장본 HardCover)
# 안녕달| 창비| 2015년 07월 27일
# 10,800원
# ---------------------
# 이기적 유전자(40주년 기념판)
# 리처드 도킨스| 을유문화사| 2018년 10월 20일
# 18,000원
# ---------------------
# 2022 제13회 젊은작가상 수상작품집
# 임솔아저자 더보기김멜라김병운김지연김혜진| 문학동네| 2022년 04월 08일
# 6,930원
# ---------------------
# 코스모스(보급판)
# 칼 세이건| 사이언스북스| 2010년 01월 20일
# 17,910원
# ---------------------
# 백년허리 1: 진단편(개정증보판)
# 정선근| 언탱글링| 2021년 04월 15일
# 16,650원
# ---------------------
# 꽃을 보듯 너를 본다(J.H CLASSIC 2)(양장본 HardCover)
# 나태주| 지혜| 2020년 11월 30일
# 9,000원
# ---------------------
# 그 비스크 돌은 사랑을 한다 9(S코믹스)
# 후쿠다 신이치| 소미미디어| 2022년 07월 14일
# 4,950원
# ---------------------
# 지리의 힘
# 팀 마샬| 사이| 2016년 08월 10일
# 15,300원
# ---------------------
# 읽으면서 바로 써먹는 어린이 수수께끼: 공포 특급(맛있는 공부 49)
# 한날| 파란정원| 2022년 07월 25일
# 11,700원
# ---------------------
# 죽이고 싶은 아이(우리학교 소설 읽는 시간)
# 이꽃님| 우리학교| 2021년 06월 07일
# 11,250원
# ---------------------
# 진짜 쓰는 실무 엑셀
# 오빠두(전진권)| 제이펍| 2022년 02월 15일
# 18,900원
# ---------------------
# 보도 섀퍼의 이기는 습관(양장본 HardCover)
# 보도 섀퍼| 토네이도| 2022년 03월 18일
# 15,300원
# ---------------------
# 킹덤 64
# 하라 야스히사| 대원씨아이| 2022년 07월 31일
# 4,950원
# ---------------------
# 으라차차 라면 가게(우당탕탕 야옹이 9)(양장본 Hardcover)
# 구도 노리코| 책읽는곰| 2022년 06월 23일
# 11,700원
# ---------------------
# 시간 고양이 2: 살인나비의 습격(책읽는 샤미 17)(양장본 Hardcover)
# 박미연| 이지북| 2022년 07월 04일
# 11,700원
# ---------------------
# 해커스 토익 스타트 리딩(Reading) RC(개정판 4판)
# David Cho| 해커스어학연구소| 2022년 02월 21일
# 13,410원
# ---------------------
# 윙페더 사가 1(양장본 HardCover)
# 앤드루 피터슨| 다산책방| 2022년 06월 28일
# 17,820원
# ---------------------
# 흔한남매 오해요
# 흔한남매 (원작)저자 더보기백난도| 미래엔아이세움| 2022년 03월 03일
# 12,150원
# ---------------------
# 잘 살아라 그게 최고의 복수다
# 권민창| 마인드셋(Mindset)| 2022년 01월 21일
# 13,500원
# ---------------------
# 오십에 읽는 논어
# 최종엽| 유노북스| 2021년 11월 03일
# 14,400원
# ---------------------
# 딸랑 예술학교 2(방울이TV)
# 방울이TV (원작)저자 더보기김언정| 학산문화사| 2022년 06월 20일
# 11,700원
# ---------------------
# 돈, 뜨겁게 사랑하고 차갑게 다루어라(코스톨라니 투자총서 1)
# 앙드레 코스톨라니| 미래의창| 2015년 09월 30일
# 10,800원
# ---------------------
# 모순(양장본 HardCover)
# 양귀자| 쓰다| 2013년 04월 01일
# 11,700원
# ---------------------
# 공정하다는 착각
# 마이클 샌델| 와이즈베리| 2020년 12월 01일
# 16,200원
# ---------------------
# 세계를 건너 너에게 갈게(문학동네청소년 39)
# 이꽃님| 문학동네| 2021년 09월 24일
# 10,350원
# ---------------------
# 돈의 심리학(10만 부 돌파 기념 골드 에디션)(양장본 Hardcover)
# 모건 하우절| 인플루엔셜| 2021년 01월 13일
# 17,820원
# ---------------------
# 극장판 포켓몬스터 뮤츠의 역습 Evolution
# 학산문화사 편집부| 학산문화사| 2020년 10월 25일
# 9,900원
# ---------------------
# 법륜 스님의 반야심경 강의(양장본 Hardcover)
# 법륜| 정토출판| 2022년 06월 30일
# 17,550원
# ---------------------
# 흔한남매 별난 방탈출 5
# 흔한남매 (원작)저자 더보기김언정| 미래엔아이세움| 2022년 05월 12일
# 11,520원
# ---------------------
# 학문의 즐거움(4판)(양장본 HardCover)
# 히로나카 헤이스케| 김영사| 2013년 04월 11일
# 11,520원
# ---------------------
# 한 권으로 끝내는 해커스 토익 700+ (LC+RC+VOCA)
# 해커스 어학연구소| 해커스어학연구소| 2022년 01월 03일
# 17,820원
# ---------------------
# 지리의 힘 2
# 팀 마샬| 사이| 2022년 04월 10일
# 20,700원
# ---------------------
# 사이다의 핸드메이드 드레스 레슨
# 사이다| 한스미디어| 2022년 07월 21일
# 22,500원
# ---------------------
# 방구석 미술관
# 조원재| 블랙피쉬| 2021년 12월 21일
# 15,120원
# ---------------------
# 도쿄 큐레이션
# 이민경| 진풍경| 2022년 07월 01일
# 20,700원
# ---------------------
# 링컨 하이웨이(양장본 Hardcover)
# 에이모 토울스| 현대문학| 2022년 07월 04일
# 17,820원
# ---------------------
# 우리가 빛의 속도로 갈 수 없다면(양장본 HardCover)
# 김초엽| 허블| 2019년 06월 24일
# 12,600원
# ---------------------
# 어떻게 말해줘야 할까(60만 부 기념 한정판 리커버)
# 오은영| 김영사| 2022년 07월 20일
# 15,750원
# ---------------------
# 반짝반짝 캐치! 티니핑 마음 성장 동화 1: 로미의 새로운 도전(양장본 HardCover)
# 아이휴먼 편집부| 아이휴먼| 2022년 02월 25일
# 10,800원
# ---------------------
# 디 에센셜: 한강(디 에센셜 한국작가 편 1)(양장본 HardCover)
# 한강| 문학동네| 2022년 05월 30일
# 15,300원
# ---------------------
# 해커스 OPIc 오픽 Advanced 공략(2주 만에 끝내는)(개정판 2판)
# 해커스 오픽연구소| 해커스| 2021년 08월 13일
# 14,310원
# ---------------------
# 우리들의 MBTI 2: 친구 관계(양장본 HardCover)
# 조수연| 다산어린이| 2022년 06월 27일
# 12,600원
# ---------------------
# 한 컷 한국사(온 세상이 교과서 시리즈 7)
# 조한경저자 더보기김남수김민수김종민박범희| 해냄에듀| 2022년 05월 30일
# 18,000원
# ---------------------
# 웃소 4
# 웃소 (원작)저자 더보기한바리| 미래엔아이세움| 2022년 06월 23일
# 12,150원
# ---------------------
# Go Go 카카오프렌즈 24: 스웨덴
# 김미영| 아울북| 2022년 05월 25일
# 10,800원
# ---------------------
# 최애의 아이 7
# Aka Akasaka저자 더보기Mengo Yokoyari| 대원씨아이| 2022년 07월 31일
# 5,400원
# ---------------------
# 한 개의 기쁨이 천 개의 슬픔을 이긴다: 일과 선택에 관하여(조우성 변호사 에세이 2)
# 조우성| 서삼독| 2022년 07월 07일
# 13,320원
# ---------------------
# 쇼코의 미소
# 최은영| 문학동네| 2019년 06월 20일
# 10,800원
# ---------------------
# 나는 둔감하게 살기로 했다(전면개정판)
# 와타나베 준이치| 다산초당| 2022년 05월 27일
# 14,400원
# ---------------------
# 웰씽킹(WEALTHINKING)(양장본 Hardcover)
# 켈리 최| 다산북스| 2021년 11월 10일
# 14,400원
# ---------------------
# 류
# 히가시야마 아키라| 해피북스투유| 2022년 06월 22일
# 13,500원
# ---------------------
# 도파민네이션
# 애나 렘키| 흐름출판| 2022년 03월 21일
# 16,200원
# ---------------------
# 나는 대출 없이 0원으로 소형 아파트를 산다
# 잭파시(최경천)| 다산북스| 2022년 04월 19일
# 18,000원
# ---------------------
# 튜브
# 손원평| 창비| 2022년 07월 22일
# 13,500원
# ---------------------
# 잘했고 잘하고 있고 잘 될 것이다(20만 부 기념 개정판)
# 정영욱| 부크럼| 2021년 05월 14일
# 13,500원
# ---------------------
# 임신 출산 육아 대백과(2021~2022)(개정판)
# 삼성출판사 편집부| 삼성출판사| 2021년 07월 31일
# 17,550원
# ---------------------
# 나미야 잡화점의 기적(양장본 Hardcover)
# 히가시노 게이고| 현대문학| 2012년 12월 19일
# 13,320원
# ---------------------
# 역량(양장본 Hardcover)
# 임춘성| 쌤앤파커스| 2022년 07월 27일
# 16,200원
# ---------------------
# 금쪽이들의 진짜 마음속(오은영 박사가 전하는)
# 오은영| 오은라이프사이언스| 2022년 05월 25일
# 17,820원
# ---------------------
# 해커스 토익 스타트 리스닝(Listening) LC(개정판 4판)
# David Cho| 해커스어학연구소| 2022년 02월 21일
# 13,410원
# ---------------------
# 클루지(CREATIVE CLASSIC SERIES)
# 개리 마커스| 갤리온| 2008년 11월 24일
# 12,420원
# ---------------------
# 소워니놀이터의 말랑말랑 스퀴시
# 조윤성| 시대인| 2022년 07월 05일
# 18,000원
# ---------------------
# 박문호 박사의 빅히스토리 공부(양장본 Hardcover)
# 박문호| 김영사| 2022년 06월 30일
# 22,500원
# ---------------------
# 마음이 흐르는 대로(양장본 HardCover)
# 지나영| 다산북스| 2020년 11월 23일
# 14,400원
# ---------------------
# 멋진 신세계
# 올더스 헉슬리| 소담출판사| 2015년 06월 12일
# 12,420원
# ---------------------
# 가짜 모범생
# 손현주| 특별한서재| 2021년 10월 15일
# 10,800원
# ---------------------
# 수학도둑 89: 응용편(코믹 메이플스토리)
# 송도수| 서울문화사| 2022년 07월 20일
# 10,800원
# ---------------------
# 내 아이를 바꾸는 위대한 질문 하브루타(바른교육 시리즈 25)
# 민혜영(하브루타 민쌤)| 서사원| 2022년 07월 07일
# 13,500원
# ---------------------
# 1984
# 조지 오웰| 소담출판사| 2021년 12월 08일
# 13,320원
# ---------------------
# 비상식적 성공 법칙(리어웨이크 시리즈 2)
# 간다 마사노리| 생각지도| 2022년 06월 30일
# 15,300원
# ---------------------
# 저 별은 모두 당신을 위해 빛나고 있다
# 손힘찬(오가타 마리토)| 떠오름| 2022년 04월 22일
# 13,680원
# ---------------------
# 소크라테스 익스프레스
# 에릭 와이너| 어크로스| 2021년 04월 28일
# 16,200원
# ---------------------
# 부자의 그릇(개정판)(양장본 HardCover)
# 이즈미 마사토| 다산북스| 2020년 12월 14일
# 13,500원
# ---------------------
# 당신은 사건 현장에 있습니다
# 모데스토 가르시아| 중앙북스| 2022년 05월 30일
# 25,200원
# ---------------------
# 경매대마왕 반드시 부자 되는 투자의 소신
# 심태승| 국일증권경제연구소| 2022년 05월 31일
# 15,300원
# ---------------------
# 감정 어휘
# 유선경| 앤의서재| 2022년 06월 10일
# 14,400원
# ---------------------
# 크다! 힘내라 동기짱 1(특장판)
# 요무| 대원씨아이| 2022년 07월 31일
# 22,500원
# ---------------------
# 초역 니체의 말(양장본 HardCover)
# 프리드리히 니체저자 더보기시라토리 하루히코 (엮음)| 삼호미디어| 2020년 03월 10일
# 12,600원
# ---------------------
# 정의란 무엇인가(마이클 샌델)
# 마이클 샌델| 와이즈베리| 2014년 11월 20일
# 13,500원
# ---------------------
# 알사탕(그림책이 참 좋아 39)(양장본 HardCover)
# 백희나| 책읽는곰| 2017년 03월 25일
# 10,800원
# ---------------------
# 아몬드(창비청소년문학 78)(반양장)
# 손원평| 창비| 2017년 03월 31일
# 9,000원
# ---------------------
# 노랜드(양장본 HardCover)
# 천선란| 한겨레출판사| 2022년 06월 22일
# 14,220원
# ---------------------
# 하늘과 바람과 별과 시(양장본 HardCover)
# 윤동주저자 더보기윤동주100년포럼 (엮음)| 스타북스| 2022년 02월 16일
# 11,700원
# ---------------------
# 체리새우: 비밀글입니다(문학동네청소년 42)
# 황영미| 문학동네| 2019년 01월 28일
# 10,350원
# ---------------------
# Give and Take(기브앤테이크)
# 애덤 그랜트| 생각연구소| 2013년 06월 07일
# 15,750원
# ---------------------
